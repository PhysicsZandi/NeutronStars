# %%
# Import physical constants
from physical_constants import *

# Import classes
from solver import *

import numpy as np

# %% [markdown]
# # Neutron Star

# %% [markdown]
# ### Non-relativistic degenerate ideal Fermi gas of neutron

# %%
file_path = "data/fermi_nonrel.csv"
eos = interpolation_eos(file_path, plot=True)
resolution = 1e3 # 1 km

# %%
# Newtonian system with running initial pressures logarithmically from 31 to 34
range_initial_pressures = np.logspace(31, 34, 100)
solver = Solver_range(eos, resolution, range_initial_pressures, relativity_corrections=False)
solver.solve()

# %%
solver.print()
# Out:
# The maximum mass is M = 0.6651850024787196 M_sun,
# which corresponds with a radius of R = 17.32000000001 km
# and a central pressure of P = 1e+34 dyne/cm^2

# %%
solver.plot()

# %%
solver.plot_RvsM()

# %%
# TOV system with running initial pressures logarithmically from 31 to 41
range_initial_pressures = np.logspace(31, 34, 100)
solver = Solver_range(eos, resolution, range_initial_pressures, relativity_corrections=True)
solver.solve()

# %%
solver.print()
# Out:
# The maximum mass is M = 0.5393599861862743 M_sun,
# which corresponds with a radius of R = 16.21000000001 km
# and a central pressure of P = 1e+34 dyne/cm^2

# %%
solver.plot()

# %%
solver.plot_RvsM()

# %% [markdown]
# ### Generic degenerate ideal Fermi gas of neutron

# %%
file_path = "data/fermi_gen.csv"
eos = interpolation_eos(file_path, plot=True)
resolution = 1e3 # 1 km

# %%
# Newtonian system with running initial pressures logarithmically from 31 to 41
range_initial_pressures = np.logspace(31, 41, 100)
solver = Solver_range(eos, resolution, range_initial_pressures, relativity_corrections=False)
solver.solve()

# %%
solver.print()
# Out:
# The maximum mass is M = 1.648618637700208 M_sun,
# which corresponds with a radius of R = 7.36000000001 km
# and a central pressure of P = 5.72236765935022e+36 dyne/cm^2

# %%
solver.plot()

# %%
solver.plot_RvsM()

# %%
# TOV system with running initial pressures from 1e31 to 1e41
range_initial_pressures = np.logspace(31, 41, 100)
solver = Solver_range(eos, resolution, range_initial_pressures, relativity_corrections=True)
solver.solve()

# %%
solver.print()
# Out:
# The maximum mass is M = 0.7104275081671337 M_sun,
# which corresponds with a radius of R = 9.22000000001 km
# and a central pressure of P = 3.5111917342151416e+35 dyne/cm^2

# %%
solver.plot()

# %%
solver.plot_RvsM()

# %% [markdown]
# ### Degenerate ideal Fermi gas of neutron, protons and electrons

# %%
file_path = "data/fermi_npe.csv"
eos = interpolation_eos(file_path, plot=True)
resolution = 1e2 # 10 km

# %%
# TOV system with running initial pressures logarithmically from 22 to 38
range_initial_pressures = np.logspace(22, 40, 100)
solver = Solver_range(eos, resolution, range_initial_pressures, relativity_corrections=True)
solver.solve()

# %%
solver.print()
# Out:
# The maximum mass is M = 4.179408854377135 M_sun,
# which corresponds with a radius of R = 11322.80000000001 km
# and a central pressure of P = 3.511191734215142e+24 dyne/cm^2

# %%
solver.plot()

# %%
# TOV system with running initial pressures logarithmically from 32.5 to 39
resolution = 1e3 # 1 km
range_initial_pressures = np.logspace(32.5, 39, 100)
solver = Solver_range(eos, resolution, range_initial_pressures, relativity_corrections=True)
solver.solve()

# %%
solver.print()
# Out:
# The maximum mass is M = 0.6993483655917097 M_sun,
# which corresponds with a radius of R = 9.29000000001 km
# and a central pressure of P = 3.312851891487241e+35 dyne/cm^2

# %%
solver.plot()

# %%
solver.plot_RvsM()

# %% [markdown]
# ### Empirical interactions

# %%
file_path = "data/emp.csv"
eos = interpolation_eos(file_path, plot=True)
resolution = 1e3 # 1 km

# %%
# TOV system with running initial pressures logarithmically from 32.5 to 40
range_initial_pressures = np.logspace(32.5, 40, 100)
solver = Solver_range(eos, resolution, range_initial_pressures, relativity_corrections=True)
solver.solve()

# %%
solver.print()
# Out:
# The maximum mass is M = 2.7923131860154293 M_sun,
# which corresponds with a radius of R = 12.53000000001 km
# and a central pressure of P = 9.657139052966038e+35 dyne/cm^2

# %%
solver.plot()

# %%
solver.plot_RvsM()

# %% [markdown]
# ### Skyrme Hatree-Fock interactions

# %%
file_path = "data/sky.csv"
eos = interpolation_eos(file_path, plot=True)
resolution = 1e3 # 1 km

# %%
# TOV system with running initial pressures logarithmically from 32.6 to 40
range_initial_pressures = np.logspace(32.6, 40, 100)
solver = Solver_range(eos, resolution, range_initial_pressures, relativity_corrections=True)
solver.solve()

# %%
solver.print()
# Out:
# The maximum mass is M = 2.438034650364957 M_sun,
# which corresponds with a radius of R = 10.97000000001 km
# and a central pressure of P = 1.2975715449664944e+36 dyne/cm^2

# %%
solver.plot()

# %%
solver.plot_RvsM()

# %% [markdown]
# ### Comparison

# %%
file_names = ["fermi_gen", "fermi_npe", "emp", "sky"]

for file_name in file_names:
    pressures = []
    energy_densities = []

    file_path = "data/" + file_name + ".csv"

    with open(f"{file_path}", "r") as file:
        next(file)
        for line in file:
            n, p, e = line.strip().split(",")
            pressures.append(float(p))
            energy_densities.append(float(e))

    plt.plot(pressures, energy_densities, label=file_name)

plt.ylabel("Energy density ($erg / cm^3$)")
plt.yscale("log")
plt.xlabel("Pressure ($dyne / cm^2$)")
plt.xscale("log")
plt.legend()
plt.show()

# %%
resolution = 1e3 # 1 km
# Generic degenerate ideal Fermi gas of neutron
file_path = "data/fermi_gen.csv"
eos = interpolation_eos(file_path)

range_initial_pressures = np.logspace(34, 40, 100)
solver = Solver_range(eos, resolution, range_initial_pressures, relativity_corrections=True)
solver.solve()

r, m = solver.get()
plt.plot(r, m, label="fermi_gen")

# Degenerate ideal Fermi gas of neutron, protons and electrons
file_path = "data/fermi_npe.csv"
eos = interpolation_eos(file_path)

range_initial_pressures = np.logspace(34, 40, 100)
solver = Solver_range(eos, resolution, range_initial_pressures, relativity_corrections=True)
solver.solve()

r, m = solver.get()
plt.plot(r, m, label="npe")

# Empirical interactions
file_path = "data/emp.csv"
eos = interpolation_eos(file_path)

range_initial_pressures = np.logspace(32.6, 40, 100)
solver = Solver_range(eos, resolution, range_initial_pressures, relativity_corrections=True)
solver.solve()

r, m = solver.get()
plt.plot(r, m, label="emp")

# Skyrme Hatree-Fock interactions
file_path = "data/sky.csv"
eos = interpolation_eos(file_path)

range_initial_pressures = np.logspace(32.7, 40, 100)
solver = Solver_range(eos, resolution, range_initial_pressures, relativity_corrections=True)
solver.solve()

r, m = solver.get()
plt.plot(r, m, label="sky")

plt.xlabel("Radius (km)")
plt.ylabel("Mass ($M_{\\odot}$)")
plt.legend()
plt.show()
