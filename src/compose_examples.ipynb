# %%
# Import classes
from compose import *

# %% [markdown]
# # CompOSE - Neutron Star EoS

# %% [markdown]
# ## All

# %%
all_eos()

# %%
all_MvsR(resolution=1e3, n_points=40)

# %% [markdown]
# ## Delta models

# %% [markdown]
# #### All

# %%
all_eos_v2(folder_initial_letters="delta")

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="delta")

# %% [markdown]
# #### Relativistic Mean Field effective interactions with hyperons and delta - R (Raduta)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="delta", file_initial_letters="R")

# %% [markdown]
# #### SU(3) Chiral Mean Field model with delta - DS (Dexheimer & Schramm)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="delta", file_initial_letters="DS")

# %% [markdown]
# #### Realistic 2-body and 3-body nuclear interactions with chiral perturbation theory - BL (Bombaci & Logoteta)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="delta", file_initial_letters="BL")

# %% [markdown]
# ## Hybrid models

# %% [markdown]
# #### All

# %%
all_eos_v2(folder_initial_letters="hybrid")

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="hybrid")

# %% [markdown]
# #### NJL model with mean field approximation - BFH (Baym, Furusawa & Hatsuda)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="hybrid", file_initial_letters="BFH")

# %% [markdown]
# #### SU(3) Chiral Mean Field model - DS (Dexheimer & Schramm)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="hybrid", file_initial_letters="DS")

# %% [markdown]
# #### Holographic V-QCD model - JJ (Jokela & Jarvinen)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="hybrid", file_initial_letters="JJ")

# %% [markdown]
# #### NJL model with the mean field approximation - KBH (Kojo, Baym & Hatsuda)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="hybrid", file_initial_letters="KBH")

# %% [markdown]
# #### Non-perturbative functional renormalization group - OOS (Otto, Oertel & Schaefer)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="hybrid", file_initial_letters="OOS")

# %% [markdown]
# ## Hyperon models

# %% [markdown]
# #### All

# %%
all_eos_v2(folder_initial_letters="hyperon")

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="hyperon")

# %% [markdown]
# #### SU(3) Chiral Mean Field model - DNS (Dexheimer, Negreiros & Schramm)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="hyperon", file_initial_letters="DNS")

# %% [markdown]
# #### SU(3) Chiral Mean Field model - DS (Dexheimer & Schramm)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="hyperon", file_initial_letters="DS")

# %% [markdown]
# #### Classical RMF parameterisation - OPGR (Oertel, Providencia, Gulminelli & Raduta)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="hyperon", file_initial_letters="OPGR")

# %% [markdown]
# ## Nucleonic models

# %% [markdown]
# #### All

# %%
all_eos_v2(folder_initial_letters="nucleonic")

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="nucleonic")

# %% [markdown]
# #### Relativistic mean-field theory constrained by Chiral EFT - ABHT (Alford, Brodie, Haber, & Tews)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="nucleonic", file_initial_letters="ABHT")

# %% [markdown]
# #### Variational method - APR (A. Akmal, Pandharipande & Ravenhall)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="nucleonic", file_initial_letters="APR")

# %% [markdown]
# #### BHF calculation - BBB (Baldo, Bombaci & Burgio)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="nucleonic", file_initial_letters="BBB")

# %% [markdown]
# #### Relativistic meta-model - CMGO (Char, Mondal, Gulminelli & Oertel)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="nucleonic", file_initial_letters="CMGO")

# %% [markdown]
# #### Classical RMF parameterisation - (Glendenning & Moszkowski)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="nucleonic", file_initial_letters="GM")

# %% [markdown]
# #### Self-consistent Thomas-Fermi approach - GPPVA (Grill, Pais, Providencia, Vidana & Avancini)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="nucleonic", file_initial_letters="GPPVA")

# %% [markdown]
# #### Relativistic mean field approximation - PCGS (Pradhan, Chatterjee, Gandhi & Schaffner)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="nucleonic", file_initial_letters="PCGS")

# %% [markdown]
# #### Extended Thomas-Fermi and Strutinski Integral framework - PCP (Pearson, Chamel & Potekhin)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="nucleonic", file_initial_letters="PCP")

# %% [markdown]
# #### Generalized relativistic density functional - PT (Pais & Typel)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="nucleonic", file_initial_letters="PT")

# %% [markdown]
# #### Cluster energy functionals - RG (Gulminelli & Raduta)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="nucleonic", file_initial_letters="RG")

# %% [markdown]
# #### Compressible Liquid Drop approach - SPG (Scurto, Pais & Gulminelli)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="nucleonic", file_initial_letters="SPG")

# %% [markdown]
# #### Variational Wigner-Kirkwood approach and Strutinsky integral method - VGBCMR (Vinas, Gonzalez-Boquera, Centelles, Mondal & Robledo)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="nucleonic", file_initial_letters="VGBCMR")

# %% [markdown]
# #### Thomas-Fermi approximation and geometrical symmetries for the Wigner-Seitz cells - XMLSLZ (Xia, Maruyama, Li, Sun, Long & Zhang)

# %%
all_MvsR_v2(resolution=1e3, n_points=40, folder_initial_letters="nucleonic", file_initial_letters="XMLSLZ")
