# %%
# Import classes
from compose import *

# %% [markdown]
# # CompOSE - Neutron Star EoS

# %% [markdown]
# ## All

# %%
all_eos()

# %%
all_MvsR()

# %% [markdown]
# ## Delta models

# %% [markdown]
# #### All

# %%
folder = "delta"

#all_eos(folder_initial_letters=folder)
all_MvsR(last_initial_pressure=36.5, folder_initial_letters=folder)

# %% [markdown]
# #### Relativistic Mean Field effective interactions with hyperons and delta - R (Raduta)

# %%
folder = "delta"
file = "R"

all_eos(folder_initial_letters=folder, file_initial_letters=file)
all_MvsR(folder_initial_letters=folder, file_initial_letters=file)

# %% [markdown]
# #### SU(3) Chiral Mean Field model with delta - DS (Dexheimer & Schramm)

# %%
folder = "delta"
file = "DS"

all_eos(folder_initial_letters=folder, file_initial_letters=file)
all_MvsR(folder_initial_letters=folder, file_initial_letters=file)

# %% [markdown]
# ## Hybrid models

# %% [markdown]
# #### All

# %%
folder = "hybrid"

#all_eos(folder_initial_letters=folder)
all_MvsR(last_initial_pressure=36.2, folder_initial_letters=folder)

# %% [markdown]
# #### NJL model with mean field approximation - BFH (Baym, Furusawa & Hatsuda)

# %%
folder = "hybrid"
file = "BFH"

all_eos_v2(folder_initial_letters=folder, file_initial_letters=file)
all_MvsR_v2(folder_initial_letters=folder, file_initial_letters=file)
all_v_v2(folder_initial_letters=folder, file_initial_letters=file)
all_z_v2(folder_initial_letters=folder, file_initial_letters=file)
all_I_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2_with_p1(folder_initial_letters=folder, file_initial_letters=file)

# %% [markdown]
# #### SU(3) Chiral Mean Field model - DS (Dexheimer & Schramm)

# %%
folder = "hybrid"
file = "DS"

all_eos_v2(folder_initial_letters=folder, file_initial_letters=file)
all_MvsR_v2(folder_initial_letters=folder, file_initial_letters=file)
all_v_v2(folder_initial_letters=folder, file_initial_letters=file)
all_z_v2(folder_initial_letters=folder, file_initial_letters=file)
all_I_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2_with_p1(folder_initial_letters=folder, file_initial_letters=file)

# %% [markdown]
# #### Holographic V-QCD model - JJ (Jokela & Jarvinen)

# %%
folder = "hybrid"
file = "JJ"

all_eos_v2(folder_initial_letters=folder, file_initial_letters=file)
all_MvsR_v2(folder_initial_letters=folder, file_initial_letters=file)
all_v_v2(folder_initial_letters=folder, file_initial_letters=file)
all_z_v2(folder_initial_letters=folder, file_initial_letters=file)
all_I_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2_with_p1(folder_initial_letters=folder, file_initial_letters=file)

# %% [markdown]
# #### NJL model with the mean field approximation - KBH (Kojo, Baym & Hatsuda)

# %%
folder = "hybrid"
file = "KBH"

all_eos_v2(folder_initial_letters=folder, file_initial_letters=file)
all_MvsR_v2(folder_initial_letters=folder, file_initial_letters=file)
all_v_v2(folder_initial_letters=folder, file_initial_letters=file)
all_z_v2(folder_initial_letters=folder, file_initial_letters=file)
all_I_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2_with_p1(folder_initial_letters=folder, file_initial_letters=file)

# %% [markdown]
# ## Hyperon models

# %% [markdown]
# #### All

# %%
folder = "hyperon"

#all_eos(folder_initial_letters=folder)
all_MvsR(last_initial_pressure=36, folder_initial_letters=folder)

# %% [markdown]
# #### SU(3) Chiral Mean Field model - DNS (Dexheimer, Negreiros & Schramm)

# %%
folder = "hyperon"
file = "DNS"

all_eos_v2(folder_initial_letters=folder, file_initial_letters=file)
all_MvsR_v2(folder_initial_letters=folder, file_initial_letters=file)
all_v_v2(folder_initial_letters=folder, file_initial_letters=file)
all_z_v2(folder_initial_letters=folder, file_initial_letters=file)
all_I_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2_with_p1(folder_initial_letters=folder, file_initial_letters=file)

# %% [markdown]
# #### SU(3) Chiral Mean Field model - DS (Dexheimer & Schramm)

# %%
folder = "hyperon"
file = "DS"

all_eos_v2(folder_initial_letters=folder, file_initial_letters=file)
all_MvsR_v2(folder_initial_letters=folder, file_initial_letters=file)
all_v_v2(folder_initial_letters=folder, file_initial_letters=file)
all_z_v2(folder_initial_letters=folder, file_initial_letters=file)
all_I_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2_with_p1(folder_initial_letters=folder, file_initial_letters=file)

# %% [markdown]
# #### Classical RMF parameterisation - OPGR (Oertel, Providencia, Gulminelli & Raduta)

# %%
folder = "hyperon"
file = "OPGR"

all_eos_v2(folder_initial_letters=folder, file_initial_letters=file)
all_MvsR_v2(folder_initial_letters=folder, file_initial_letters=file)
all_v_v2(folder_initial_letters=folder, file_initial_letters=file)
all_z_v2(folder_initial_letters=folder, file_initial_letters=file)
all_I_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2_with_p1(folder_initial_letters=folder, file_initial_letters=file)

# %% [markdown]
# ## Nucleonic models

# %% [markdown]
# #### All

# %%
folder = "nucleonic"

#all_eos(folder_initial_letters=folder)
all_MvsR(36.2, folder_initial_letters=folder)

# %% [markdown]
# #### Relativistic mean-field theory constrained by Chiral EFT - ABHT (Alford, Brodie, Haber, & Tews)

# %%
folder = "nucleonic"
file = "ABHT"

all_eos_v2(folder_initial_letters=folder, file_initial_letters=file)
all_MvsR_v2(folder_initial_letters=folder, file_initial_letters=file)
all_v_v2(folder_initial_letters=folder, file_initial_letters=file)
all_z_v2(folder_initial_letters=folder, file_initial_letters=file)
all_I_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2_with_p1(folder_initial_letters=folder, file_initial_letters=file)

# %% [markdown]
# #### Variational method - APR (A. Akmal, Pandharipande & Ravenhall)

# %%
folder = "nucleonic"
file = "APR"

all_eos_v2(folder_initial_letters=folder, file_initial_letters=file)
all_MvsR_v2(folder_initial_letters=folder, file_initial_letters=file)
all_v_v2(folder_initial_letters=folder, file_initial_letters=file)
all_z_v2(folder_initial_letters=folder, file_initial_letters=file)
all_I_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2_with_p1(folder_initial_letters=folder, file_initial_letters=file)

# %% [markdown]
# #### BHF calculation - BBB (Baldo, Bombaci & Burgio)

# %%
folder = "nucleonic"
file = "BBB"

#all_eos_v2(folder_initial_letters=folder, file_initial_letters=file)
all_MvsR_v2(folder_initial_letters=folder, file_initial_letters=file)
#all_v_v2(folder_initial_letters=folder, file_initial_letters=file)
#all_z_v2(folder_initial_letters=folder, file_initial_letters=file)
#all_I_v2(folder_initial_letters=folder, file_initial_letters=file)
#all_parameters_v2(folder_initial_letters=folder, file_initial_letters=file)
#all_parameters_v2_with_p1(folder_initial_letters=folder, file_initial_letters=file)

# %% [markdown]
# #### Relativistic meta-model - CMGO (Char, Mondal, Gulminelli & Oertel)

# %%
folder = "nucleonic"
file = "CMGO"

all_eos_v2(folder_initial_letters=folder, file_initial_letters=file)
all_MvsR_v2(folder_initial_letters=folder, file_initial_letters=file)
all_v_v2(folder_initial_letters=folder, file_initial_letters=file)
all_z_v2(folder_initial_letters=folder, file_initial_letters=file)
all_I_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2_with_p1(folder_initial_letters=folder, file_initial_letters=file)

# %% [markdown]
# #### Classical RMF parameterisation - GM (Glendenning & Moszkowski)

# %%
folder = "nucleonic"
file = "GM"

all_eos_v2(folder_initial_letters=folder, file_initial_letters=file)
all_MvsR_v2(folder_initial_letters=folder, file_initial_letters=file)
all_v_v2(folder_initial_letters=folder, file_initial_letters=file)
all_z_v2(folder_initial_letters=folder, file_initial_letters=file)
all_I_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2_with_p1(folder_initial_letters=folder, file_initial_letters=file)

# %% [markdown]
# #### Self-consistent Thomas-Fermi approach - GPPVA (Grill, Pais, Providencia, Vidana & Avancini)

# %%
folder = "nucleonic"
file = "GPPVA"

all_eos_v2(folder_initial_letters=folder, file_initial_letters=file)
all_MvsR_v2(folder_initial_letters=folder, file_initial_letters=file)
all_v_v2(folder_initial_letters=folder, file_initial_letters=file)
all_z_v2(folder_initial_letters=folder, file_initial_letters=file)
all_I_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2_with_p1(folder_initial_letters=folder, file_initial_letters=file)

# %% [markdown]
# #### Relativistic mean field approximation - PCGS (Pradhan, Chatterjee, Gandhi & Schaffner)

# %%
folder = "nucleonic"
file = "PCGS"

all_eos_v2(folder_initial_letters=folder, file_initial_letters=file)
all_MvsR_v2(folder_initial_letters=folder, file_initial_letters=file)
all_v_v2(folder_initial_letters=folder, file_initial_letters=file)
all_z_v2(folder_initial_letters=folder, file_initial_letters=file)
all_I_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2_with_p1(folder_initial_letters=folder, file_initial_letters=file)

# %% [markdown]
# #### Extended Thomas-Fermi and Strutinski Integral framework - PCP (Pearson, Chamel & Potekhin)

# %%
folder = "nucleonic"
file = "PCP"

all_eos_v2(folder_initial_letters=folder, file_initial_letters=file)
all_MvsR_v2(folder_initial_letters=folder, file_initial_letters=file)
all_v_v2(folder_initial_letters=folder, file_initial_letters=file)
all_z_v2(folder_initial_letters=folder, file_initial_letters=file)
all_I_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2_with_p1(folder_initial_letters=folder, file_initial_letters=file)

# %% [markdown]
# #### Generalized relativistic density functional - PT (Pais & Typel)

# %%
folder = "nucleonic"
file = "PT"

all_eos_v2(folder_initial_letters=folder, file_initial_letters=file)
all_MvsR_v2(folder_initial_letters=folder, file_initial_letters=file)
all_v_v2(folder_initial_letters=folder, file_initial_letters=file)
all_z_v2(folder_initial_letters=folder, file_initial_letters=file)
all_I_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2_with_p1(folder_initial_letters=folder, file_initial_letters=file)

# %% [markdown]
# #### Cluster energy functionals - RG (Gulminelli & Raduta)

# %%
folder = "nucleonic"
file = "RG"

all_eos_v2(folder_initial_letters=folder, file_initial_letters=file)
all_MvsR_v2(folder_initial_letters=folder, file_initial_letters=file)
all_v_v2(folder_initial_letters=folder, file_initial_letters=file)
all_z_v2(folder_initial_letters=folder, file_initial_letters=file)
all_I_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2_with_p1(folder_initial_letters=folder, file_initial_letters=file)

# %% [markdown]
# #### Compressible Liquid Drop approach - SPG (Scurto, Pais & Gulminelli)

# %%
folder = "nucleonic"
file = "SPG"

all_eos_v2(folder_initial_letters=folder, file_initial_letters=file)
all_MvsR_v2(folder_initial_letters=folder, file_initial_letters=file)
all_v_v2(folder_initial_letters=folder, file_initial_letters=file)
all_z_v2(folder_initial_letters=folder, file_initial_letters=file)
all_I_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2_with_p1(folder_initial_letters=folder, file_initial_letters=file)

# %% [markdown]
# #### Variational Wigner-Kirkwood approach and Strutinsky integral method - VGBCMR (Vinas, Gonzalez-Boquera, Centelles, Mondal & Robledo)

# %%
folder = "nucleonic"
file = "VGBCMR"

all_eos_v2(folder_initial_letters=folder, file_initial_letters=file)
all_MvsR_v2(folder_initial_letters=folder, file_initial_letters=file)
all_v_v2(folder_initial_letters=folder, file_initial_letters=file)
all_z_v2(folder_initial_letters=folder, file_initial_letters=file)
all_I_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2(folder_initial_letters=folder, file_initial_letters=file)
all_parameters_v2_with_p1(folder_initial_letters=folder, file_initial_letters=file)

# %% [markdown]
# #### Thomas-Fermi approximation and geometrical symmetries for the Wigner-Seitz cells - XMLSLZ (Xia, Maruyama, Li, Sun, Long & Zhang)

# %%
from compose import *
folder = "nucleonic"
file = "XMLSLZ"

# all_eos_v2(folder_initial_letters=folder, file_initial_letters=file)
all_MvsR_v2(folder_initial_letters=folder, file_initial_letters=file)
#all_v_v2(folder_initial_letters=folder, file_initial_letters=file)
#all_z_v2(folder_initial_letters=folder, file_initial_letters=file)
#all_I_v2(folder_initial_letters=folder, file_initial_letters=file)
#all_parameters_v2(folder_initial_letters=folder, file_initial_letters=file)
#all_parameters_v2_with_p1(folder_initial_letters=folder, file_initial_letters=file)

# %% [markdown]
# ### Try

# %%
all_MvsR(file_initial_letters="D")
